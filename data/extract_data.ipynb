# %%
import lyricsgenius as lg
import pandas as pd
import numpy as np
import requests
import pandas as pd
import requests

# %%
import re 
import urllib.request 
from bs4 import BeautifulSoup 
 
def get_lyrics(artist,song_title, proxies): 
    
    artist = artist.lower() 
    song_title = song_title.lower() 
    print(artist)
    print(song_title)
    # remove all except alphanumeric characters from artist and song_title 
    artist = re.sub('[^A-Za-z0-9]+', "", artist) 
    song_title = re.sub('[^A-Za-z0-9]+', "", song_title) 
    if artist.startswith("the"):    # remove starting 'the' from artist e.g. the who -> who 
        artist = artist[3:] 
    url = "http://azlyrics.com/lyrics/"+artist+"/"+song_title+".html" 
     
    try: 
        content = urllib.request.urlopen(url).read() 
        soup = BeautifulSoup(content, 'html.parser') 
        lyrics = str(soup) 
        # lyrics lies between up_partition and down_partition 
        up_partition = '<!-- Usage of azlyrics.com content by any third-party lyrics provider is prohibited by our licensing agreement. Sorry about that. -->' 
        down_partition = '<!-- MxM banner -->' 
        lyrics = lyrics.split(up_partition)[1] 
        lyrics = lyrics.split(down_partition)[0] 
        lyrics = lyrics.replace('<br>','').replace('</br>','').replace('</div>','').strip() 
        return lyrics 
    except Exception as e: 
        return "Exception occurred \n" +str(e)

# %%
def get_results(album_id,sp):
    results = sp.playlist(album_id)
    return results

def get_dataframe_from_album(results, sp, next = False):
    
    if next == False:
        results_tracks = results['tracks']
    
        songs = results_tracks['items']
    else:
        songs = results['items']

    list_id = []
    list_name = []
    list_artist = []
    list_disc = []
    list_duration = []
    list_episode = []
    list_explicit = []
    list_popularity = []
    list_danceability = []
    list_acousticness = []
    list_energy = [] 
    list_instrumentalness = []
    list_liveness = []
    list_loudness = []
    list_mode = []
    list_speechiness = []
    list_tempo = []
    list_time_signature = []
    list_valence = []
    if next == False:
        for i in songs:
            audio_features = sp.audio_features(i['track']['id'])[0]
            list_id.append(i['track']['id'])
            list_name.append(i['track']['name'])
            list_artist.append(i['track']['artists'][0]['name'])
            list_disc.append(i['track']['disc_number'])
            list_duration.append(i['track']['duration_ms'])
            list_episode.append(i['track']['episode'])
            list_explicit.append(i['track']['explicit'])
            list_popularity.append(i['track']['popularity'])
            list_danceability.append(audio_features['danceability'])
            list_acousticness.append(audio_features['acousticness'])
            list_energy.append(audio_features['energy'])
            list_instrumentalness.append(audio_features['instrumentalness'])
            list_liveness.append(audio_features['liveness'])
            list_loudness.append(audio_features['loudness'])
            list_mode.append(audio_features['mode'])
            list_speechiness.append(audio_features['speechiness'])
            list_tempo.append(audio_features['tempo'])
            list_time_signature.append(audio_features['time_signature'])
            list_valence.append(audio_features['valence'])
    else:
        for i in songs:
            audio_features = sp.audio_features(i['id'])[0]
            list_id.append(i['id'])
            list_name.append(i['name'])
            list_artist.append(i['artists'][0]['name'])
            list_disc.append(i['disc_number'])
            list_duration.append(i['duration_ms'])
            list_episode.append(i['episode'])
            list_explicit.append(i['explicit'])
            list_popularity.append(i['popularity'])
            list_danceability.append(audio_features['danceability'])
            list_acousticness.append(audio_features['acousticness'])
            list_energy.append(audio_features['energy'])
            list_instrumentalness.append(audio_features['instrumentalness'])
            list_liveness.append(audio_features['liveness'])
            list_loudness.append(audio_features['loudness'])
            list_mode.append(audio_features['mode'])
            list_speechiness.append(audio_features['speechiness'])
            list_tempo.append(audio_features['tempo'])
            list_time_signature.append(audio_features['time_signature'])
            list_valence.append(audio_features['valence'])

    data = {'id':list_id,
    'name':list_name,
    'artist':list_artist,
    'disc':list_disc,
    'duration':list_duration,
    'episode':list_episode,
    'explicit':list_explicit,
    'popularity':list_popularity,
    'danceability':list_danceability,
    'acousticness':list_acousticness,
    'energy':list_energy,
    'instrumentalness':list_instrumentalness,
    'liveness':list_liveness,
    'loudness':list_loudness,
    'mode':list_mode,
    'speechiness':list_speechiness,
    'tempo':list_tempo,
    'time_signature':list_time_signature,
    'valence':list_valence}

    dataset = pd.DataFrame(data)

    return dataset,results

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = '1e84f4ee200940d584627e45098e5951'
client_secret = '4b20974001e9495b8f4dbe22d9a18c01'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager
=
client_credentials_manager)

# %%
dataset,results = get_dataframe_from_album(get_results('5Y4SqLno1w1PkXYuvgwo6p', sp),sp)
dataset_2 = get_dataframe_from_album(sp.next(get_results('5Y4SqLno1w1PkXYuvgwo6p', sp)['tracks']),sp, next =True)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data mining and visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data%20mining%20and%20visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb#ch0000014?line=0'>1</a> dataset,results = get_dataframe_from_album(get_results('5Y4SqLno1w1PkXYuvgwo6p', sp),sp)
# ----> <a href='vscode-notebook-cell:/Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data%20mining%20and%20visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb#ch0000014?line=1'>2</a> dataset_2 = get_dataframe_from_album(sp.next(get_results('5Y4SqLno1w1PkXYuvgwo6p', sp)['tracks']),sp, next =True)[0]
#
# /Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data mining and visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb Cell 5 in get_dataframe_from_album(results, sp, next)
#      <a href='vscode-notebook-cell:/Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data%20mining%20and%20visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb#ch0000014?line=54'>55</a> else:
#      <a href='vscode-notebook-cell:/Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data%20mining%20and%20visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb#ch0000014?line=55'>56</a>     for i in songs:
# ---> <a href='vscode-notebook-cell:/Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data%20mining%20and%20visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb#ch0000014?line=56'>57</a>         audio_features = sp.audio_features(i['id'])[0]
#      <a href='vscode-notebook-cell:/Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data%20mining%20and%20visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb#ch0000014?line=57'>58</a>         list_id.append(i['id'])
#      <a href='vscode-notebook-cell:/Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data%20mining%20and%20visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb#ch0000014?line=58'>59</a>         list_name.append(i['name'])
#
# KeyError: 'id'

# %%
sp.next(get_results('5Y4SqLno1w1PkXYuvgwo6p', sp)['tracks'])['items']
# Out:
# [{'added_at': '2021-09-09T01:32:01Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lAWpj5szCSwM4rUMHYmrr'},
#       'href': 'https://api.spotify.com/v1/artists/0lAWpj5szCSwM4rUMHYmrr',
#       'id': '0lAWpj5szCSwM4rUMHYmrr',
#       'name': 'Måneskin',
#       'type': 'artist',
#       'uri': 'spotify:artist:0lAWpj5szCSwM4rUMHYmrr'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7KF1Ain9mYYlg5M46g0i4A'},
#     'href': 'https://api.spotify.com/v1/albums/7KF1Ain9mYYlg5M46g0i4A',
#     'id': '7KF1Ain9mYYlg5M46g0i4A',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735aa05015cfa7bd2943c29b21',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025aa05015cfa7bd2943c29b21',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515aa05015cfa7bd2943c29b21',
#       'width': 64}],
#     'name': "Teatro d'ira - Vol. I",
#     'release_date': '2021-03-19',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:7KF1Ain9mYYlg5M46g0i4A'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lAWpj5szCSwM4rUMHYmrr'},
#      'href': 'https://api.spotify.com/v1/artists/0lAWpj5szCSwM4rUMHYmrr',
#      'id': '0lAWpj5szCSwM4rUMHYmrr',
#      'name': 'Måneskin',
#      'type': 'artist',
#      'uri': 'spotify:artist:0lAWpj5szCSwM4rUMHYmrr'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 173346,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'ITB002100115'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4pt5fDVTg5GhEvEtlz9dKk'},
#    'href': 'https://api.spotify.com/v1/tracks/4pt5fDVTg5GhEvEtlz9dKk',
#    'id': '4pt5fDVTg5GhEvEtlz9dKk',
#    'is_local': False,
#    'name': 'I WANNA BE YOUR SLAVE',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/485950694eaee2c2887f897603a9bc4acc05c0bf?cid=1e84f4ee200940d584627e45098e5951',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4pt5fDVTg5GhEvEtlz9dKk'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T01:41:23Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62DKpfVgNt372d3Zz6TRc7'},
#       'href': 'https://api.spotify.com/v1/artists/62DKpfVgNt372d3Zz6TRc7',
#       'id': '62DKpfVgNt372d3Zz6TRc7',
#       'name': 'Teddy Hyde',
#       'type': 'artist',
#       'uri': 'spotify:artist:62DKpfVgNt372d3Zz6TRc7'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4y65KFlZgIAVqy97RXLuZq'},
#     'href': 'https://api.spotify.com/v1/albums/4y65KFlZgIAVqy97RXLuZq',
#     'id': '4y65KFlZgIAVqy97RXLuZq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e2cc9f846d54bdcb401f6962',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e2cc9f846d54bdcb401f6962',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e2cc9f846d54bdcb401f6962',
#       'width': 64}],
#     'name': 'Sock-Footed',
#     'release_date': '2018-04-02',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4y65KFlZgIAVqy97RXLuZq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62DKpfVgNt372d3Zz6TRc7'},
#      'href': 'https://api.spotify.com/v1/artists/62DKpfVgNt372d3Zz6TRc7',
#      'id': '62DKpfVgNt372d3Zz6TRc7',
#      'name': 'Teddy Hyde',
#      'type': 'artist',
#      'uri': 'spotify:artist:62DKpfVgNt372d3Zz6TRc7'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 232811,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'uscgj1853748'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1baoZlq32nBee9tcYbQYxV'},
#    'href': 'https://api.spotify.com/v1/tracks/1baoZlq32nBee9tcYbQYxV',
#    'id': '1baoZlq32nBee9tcYbQYxV',
#    'is_local': False,
#    'name': 'Sex with a Ghost',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:1baoZlq32nBee9tcYbQYxV'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T01:41:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hWM8sF4FGYM2mv5pEaDMJ'},
#       'href': 'https://api.spotify.com/v1/artists/0hWM8sF4FGYM2mv5pEaDMJ',
#       'id': '0hWM8sF4FGYM2mv5pEaDMJ',
#       'name': 'Charlie Mole',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hWM8sF4FGYM2mv5pEaDMJ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/56VlzDua2bCTkP5cmsjdxW'},
#     'href': 'https://api.spotify.com/v1/albums/56VlzDua2bCTkP5cmsjdxW',
#     'id': '56VlzDua2bCTkP5cmsjdxW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e9ce6450ac69a6fbe28afd98',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e9ce6450ac69a6fbe28afd98',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e9ce6450ac69a6fbe28afd98',
#       'width': 64}],
#     'name': 'Dorian Gray (Original Score Soundtrack)',
#     'release_date': '2012',
#     'release_date_precision': 'year',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:56VlzDua2bCTkP5cmsjdxW'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hWM8sF4FGYM2mv5pEaDMJ'},
#      'href': 'https://api.spotify.com/v1/artists/0hWM8sF4FGYM2mv5pEaDMJ',
#      'id': '0hWM8sF4FGYM2mv5pEaDMJ',
#      'name': 'Charlie Mole',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hWM8sF4FGYM2mv5pEaDMJ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 143666,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GB2H71200002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/32nuyvpiQJoGUUrORIEhwu'},
#    'href': 'https://api.spotify.com/v1/tracks/32nuyvpiQJoGUUrORIEhwu',
#    'id': '32nuyvpiQJoGUUrORIEhwu',
#    'is_local': False,
#    'name': "Dorian's Theme",
#    'popularity': 35,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ef3bcaffda7945cef31a348118c2987269cbf9d8?cid=1e84f4ee200940d584627e45098e5951',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:32nuyvpiQJoGUUrORIEhwu'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T01:42:36Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#       'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#       'id': '0e86yPdC41PGRkLp2Q1Bph',
#       'name': 'Mother Mother',
#       'type': 'artist',
#       'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0X7S0TEZ5NJsSxmyTnfYi2'},
#     'href': 'https://api.spotify.com/v1/albums/0X7S0TEZ5NJsSxmyTnfYi2',
#     'id': '0X7S0TEZ5NJsSxmyTnfYi2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736d82586633548d5c122ee00c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026d82586633548d5c122ee00c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516d82586633548d5c122ee00c',
#       'width': 64}],
#     'name': 'O My Heart',
#     'release_date': '2008-09-23',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0X7S0TEZ5NJsSxmyTnfYi2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#      'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#      'id': '0e86yPdC41PGRkLp2Q1Bph',
#      'name': 'Mother Mother',
#      'type': 'artist',
#      'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 213573,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAL450882106'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0VmREvheUiN0xgM5fJYQqp'},
#    'href': 'https://api.spotify.com/v1/tracks/0VmREvheUiN0xgM5fJYQqp',
#    'id': '0VmREvheUiN0xgM5fJYQqp',
#    'is_local': False,
#    'name': 'Body',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/37e0b92988620e92f2562f67a998bdc9b986ab36?cid=1e84f4ee200940d584627e45098e5951',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0VmREvheUiN0xgM5fJYQqp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T01:42:43Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Avni6DLpoxtanND8mG5t8'},
#       'href': 'https://api.spotify.com/v1/artists/3Avni6DLpoxtanND8mG5t8',
#       'id': '3Avni6DLpoxtanND8mG5t8',
#       'name': 'Ghost and Pals',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Avni6DLpoxtanND8mG5t8'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5pQ3seSamWt2dGyOjFhpNz'},
#     'href': 'https://api.spotify.com/v1/albums/5pQ3seSamWt2dGyOjFhpNz',
#     'id': '5pQ3seSamWt2dGyOjFhpNz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733937671024330a766b80964a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023937671024330a766b80964a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513937671024330a766b80964a',
#       'width': 64}],
#     'name': "Honey I'm Home",
#     'release_date': '2019-08-18',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:5pQ3seSamWt2dGyOjFhpNz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Avni6DLpoxtanND8mG5t8'},
#      'href': 'https://api.spotify.com/v1/artists/3Avni6DLpoxtanND8mG5t8',
#      'id': '3Avni6DLpoxtanND8mG5t8',
#      'name': 'Ghost and Pals',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Avni6DLpoxtanND8mG5t8'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 213085,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZFZ71935711'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6mi1qJnxW164dbHszk32z5'},
#    'href': 'https://api.spotify.com/v1/tracks/6mi1qJnxW164dbHszk32z5',
#    'id': '6mi1qJnxW164dbHszk32z5',
#    'is_local': False,
#    'name': "Honey I'm Home",
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/977216ad453bc7e1ad20c8dcb29c1e1810750d58?cid=1e84f4ee200940d584627e45098e5951',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6mi1qJnxW164dbHszk32z5'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T01:42:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yrzVTuk6PgF51NYgfgKXe'},
#       'href': 'https://api.spotify.com/v1/artists/0yrzVTuk6PgF51NYgfgKXe',
#       'id': '0yrzVTuk6PgF51NYgfgKXe',
#       'name': 'GRLwood',
#       'type': 'artist',
#       'uri': 'spotify:artist:0yrzVTuk6PgF51NYgfgKXe'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1R2Ky437vHsCBUGwKoVcmK'},
#     'href': 'https://api.spotify.com/v1/albums/1R2Ky437vHsCBUGwKoVcmK',
#     'id': '1R2Ky437vHsCBUGwKoVcmK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273428ea052133803b881fcde8b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02428ea052133803b881fcde8b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851428ea052133803b881fcde8b',
#       'width': 64}],
#     'name': 'Daddy',
#     'release_date': '2018-06-15',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:1R2Ky437vHsCBUGwKoVcmK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yrzVTuk6PgF51NYgfgKXe'},
#      'href': 'https://api.spotify.com/v1/artists/0yrzVTuk6PgF51NYgfgKXe',
#      'id': '0yrzVTuk6PgF51NYgfgKXe',
#      'name': 'GRLwood',
#      'type': 'artist',
#      'uri': 'spotify:artist:0yrzVTuk6PgF51NYgfgKXe'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 144108,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USGAC1800077'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0GxbglYySl18aZDIaGu1RU'},
#    'href': 'https://api.spotify.com/v1/tracks/0GxbglYySl18aZDIaGu1RU',
#    'id': '0GxbglYySl18aZDIaGu1RU',
#    'is_local': False,
#    'name': "I'm Yer Dad",
#    'popularity': 5,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0GxbglYySl18aZDIaGu1RU'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T01:48:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#       'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#       'id': '5Lz5CnywFeg4Rs4l76OtG2',
#       'name': 'KiNG MALA',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5vlaew4MTOnlOfon5T0vfK'},
#     'href': 'https://api.spotify.com/v1/albums/5vlaew4MTOnlOfon5T0vfK',
#     'id': '5vlaew4MTOnlOfon5T0vfK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395ea5ca32e4d5c8d65188b97',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295ea5ca32e4d5c8d65188b97',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195ea5ca32e4d5c8d65188b97',
#       'width': 64}],
#     'name': 'mercy',
#     'release_date': '2021-07-22',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5vlaew4MTOnlOfon5T0vfK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#      'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#      'id': '5Lz5CnywFeg4Rs4l76OtG2',
#      'name': 'KiNG MALA',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 177788,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZ9H32100021'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4PHZkpHmsig3EihQneGOMt'},
#    'href': 'https://api.spotify.com/v1/tracks/4PHZkpHmsig3EihQneGOMt',
#    'id': '4PHZkpHmsig3EihQneGOMt',
#    'is_local': False,
#    'name': 'mercy',
#    'popularity': 47,
#    'preview_url': 'https://p.scdn.co/mp3-preview/31fcecc98ab44fc64c020d3298059aff4817eaae?cid=1e84f4ee200940d584627e45098e5951',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4PHZkpHmsig3EihQneGOMt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T01:48:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#       'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#       'id': '5Lz5CnywFeg4Rs4l76OtG2',
#       'name': 'KiNG MALA',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6A32eeBvBEw5bh6w2PDPyf'},
#     'href': 'https://api.spotify.com/v1/albums/6A32eeBvBEw5bh6w2PDPyf',
#     'id': '6A32eeBvBEw5bh6w2PDPyf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27388726cc9069a3677ae7ef7c6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0288726cc9069a3677ae7ef7c6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485188726cc9069a3677ae7ef7c6',
#       'width': 64}],
#     'name': 'If I Try to Find You',
#     'release_date': '2020-09-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6A32eeBvBEw5bh6w2PDPyf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#      'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#      'id': '5Lz5CnywFeg4Rs4l76OtG2',
#      'name': 'KiNG MALA',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 227817,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZ9H32000041'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6T677KlIOsgJNAJaoVWZut'},
#    'href': 'https://api.spotify.com/v1/tracks/6T677KlIOsgJNAJaoVWZut',
#    'id': '6T677KlIOsgJNAJaoVWZut',
#    'is_local': False,
#    'name': 'If I Try to Find You',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6T677KlIOsgJNAJaoVWZut'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T01:48:24Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#       'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#       'id': '5Lz5CnywFeg4Rs4l76OtG2',
#       'name': 'KiNG MALA',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0FlT3HWoxUWcVTZHV2oYfd'},
#     'href': 'https://api.spotify.com/v1/albums/0FlT3HWoxUWcVTZHV2oYfd',
#     'id': '0FlT3HWoxUWcVTZHV2oYfd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f09f395bd8eef832952ede3f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f09f395bd8eef832952ede3f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f09f395bd8eef832952ede3f',
#       'width': 64}],
#     'name': 'GEMiNi',
#     'release_date': '2020-12-04',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:0FlT3HWoxUWcVTZHV2oYfd'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#      'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#      'id': '5Lz5CnywFeg4Rs4l76OtG2',
#      'name': 'KiNG MALA',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 150304,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZ9H32000081'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3wdR1Tu976HOacAvIfM36l'},
#    'href': 'https://api.spotify.com/v1/tracks/3wdR1Tu976HOacAvIfM36l',
#    'id': '3wdR1Tu976HOacAvIfM36l',
#    'is_local': False,
#    'name': 'Funeral',
#    'popularity': 34,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3191c385367173834358c4b246d6ce0b10ae7d22?cid=1e84f4ee200940d584627e45098e5951',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:3wdR1Tu976HOacAvIfM36l'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T01:48:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VwCIS8jdx9ZHjApLFNrTZ'},
#       'href': 'https://api.spotify.com/v1/artists/5VwCIS8jdx9ZHjApLFNrTZ',
#       'id': '5VwCIS8jdx9ZHjApLFNrTZ',
#       'name': 'Noga Erez',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VwCIS8jdx9ZHjApLFNrTZ'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/55JRBOOVB5twmQbydWvzBc'},
#     'href': 'https://api.spotify.com/v1/albums/55JRBOOVB5twmQbydWvzBc',
#     'id': '55JRBOOVB5twmQbydWvzBc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273488e610297ff1500051c0b2c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02488e610297ff1500051c0b2c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851488e610297ff1500051c0b2c',
#       'width': 64}],
#     'name': 'KIDS',
#     'release_date': '2021-03-26',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:55JRBOOVB5twmQbydWvzBc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VwCIS8jdx9ZHjApLFNrTZ'},
#      'href': 'https://api.spotify.com/v1/artists/5VwCIS8jdx9ZHjApLFNrTZ',
#      'id': '5VwCIS8jdx9ZHjApLFNrTZ',
#      'name': 'Noga Erez',
#      'type': 'artist',
#      'uri': 'spotify:artist:5VwCIS8jdx9ZHjApLFNrTZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 160922,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DED622000082'},
# ...
#       'url': 'https://i.scdn.co/image/ab67616d00001e0244e74fdbaeda913b79c6fdfe',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485144e74fdbaeda913b79c6fdfe',
#       'width': 64}],
#     'name': 'Sweet Dreams (Sky like Dreams)',
#     'release_date': '2023-05-05',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:6NKax6Y6wVnv0v6dG7yC5f'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gIGkRqCo4NK2PUCI8u4aQ'},
#      'href': 'https://api.spotify.com/v1/artists/2gIGkRqCo4NK2PUCI8u4aQ',
#      'id': '2gIGkRqCo4NK2PUCI8u4aQ',
#      'name': 'Ferdinand fka Left Boy',
#      'type': 'artist',
#      'uri': 'spotify:artist:2gIGkRqCo4NK2PUCI8u4aQ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 110270,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'DEE862300763'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3zrwQpsIrGxLUwxq4iMvfk'},
#    'href': 'https://api.spotify.com/v1/tracks/3zrwQpsIrGxLUwxq4iMvfk',
#    'id': '3zrwQpsIrGxLUwxq4iMvfk',
#    'is_local': False,
#    'name': 'Sweet Dreams (Sky like Dreams) - Sped up',
#    'popularity': 61,
#    'preview_url': 'https://p.scdn.co/mp3-preview/bcd02564a465667ac7bcd779e7cd54799ff915e8?cid=1e84f4ee200940d584627e45098e5951',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3zrwQpsIrGxLUwxq4iMvfk'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-11T14:13:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3JsMj0DEzyWc0VDlHuy9Bx'},
#       'href': 'https://api.spotify.com/v1/artists/3JsMj0DEzyWc0VDlHuy9Bx',
#       'id': '3JsMj0DEzyWc0VDlHuy9Bx',
#       'name': 'Supertramp',
#       'type': 'artist',
#       'uri': 'spotify:artist:3JsMj0DEzyWc0VDlHuy9Bx'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1zcm3UvHNHpseYOUfd0pna'},
#     'href': 'https://api.spotify.com/v1/albums/1zcm3UvHNHpseYOUfd0pna',
#     'id': '1zcm3UvHNHpseYOUfd0pna',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735405ef9e393f5f1e53b4b42e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025405ef9e393f5f1e53b4b42e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515405ef9e393f5f1e53b4b42e',
#       'width': 64}],
#     'name': 'Breakfast In America (Deluxe Edition)',
#     'release_date': '1979-03-29',
#     'release_date_precision': 'day',
#     'total_tracks': 22,
#     'type': 'album',
#     'uri': 'spotify:album:1zcm3UvHNHpseYOUfd0pna'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3JsMj0DEzyWc0VDlHuy9Bx'},
#      'href': 'https://api.spotify.com/v1/artists/3JsMj0DEzyWc0VDlHuy9Bx',
#      'id': '3JsMj0DEzyWc0VDlHuy9Bx',
#      'name': 'Supertramp',
#      'type': 'artist',
#      'uri': 'spotify:artist:3JsMj0DEzyWc0VDlHuy9Bx'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 159346,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71021483'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4a5pNRjwmzYQuEY1E7O6pj'},
#    'href': 'https://api.spotify.com/v1/tracks/4a5pNRjwmzYQuEY1E7O6pj',
#    'id': '4a5pNRjwmzYQuEY1E7O6pj',
#    'is_local': False,
#    'name': 'Breakfast In America - 2010 Remastered',
#    'popularity': 76,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4a5pNRjwmzYQuEY1E7O6pj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-07-12T13:41:01Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#    'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#    'id': 'fjs07o44hm09c5rmgfi96q5jc',
#    'type': 'user',
#    'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#       'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#       'id': '0e86yPdC41PGRkLp2Q1Bph',
#       'name': 'Mother Mother',
#       'type': 'artist',
#       'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0X7S0TEZ5NJsSxmyTnfYi2'},
#     'href': 'https://api.spotify.com/v1/albums/0X7S0TEZ5NJsSxmyTnfYi2',
#     'id': '0X7S0TEZ5NJsSxmyTnfYi2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736d82586633548d5c122ee00c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026d82586633548d5c122ee00c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516d82586633548d5c122ee00c',
#       'width': 64}],
#     'name': 'O My Heart',
#     'release_date': '2008-09-23',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0X7S0TEZ5NJsSxmyTnfYi2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#      'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#      'id': '0e86yPdC41PGRkLp2Q1Bph',
#      'name': 'Mother Mother',
#      'type': 'artist',
#      'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 194320,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAL450882109'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2y51QpLzI5qbWfCcSx9Tu1'},
#    'href': 'https://api.spotify.com/v1/tracks/2y51QpLzI5qbWfCcSx9Tu1',
#    'id': '2y51QpLzI5qbWfCcSx9Tu1',
#    'is_local': False,
#    'name': 'Wrecking Ball',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c0182d49a81e64f1515c36837877460ffde2e83b?cid=1e84f4ee200940d584627e45098e5951',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:2y51QpLzI5qbWfCcSx9Tu1'},
#   'video_thumbnail': {'url': None}}]

# %%
dataset['lyrics'] = dataset.apply(lambda row: get_lyrics(row['artist'], row['name']), axis =1)
# Out:
# gipsy kings
# hotel california - spanish mix
# bobby womack
# fly me to the moon (in other words)
# the band
# the weight - remastered 2000
# moriarty
# jimmy
# canned heat
# going up the country
# don mclean
# american pie
# the doors
# people are strange
# serge fiori
# pour un instant
# john lennon
# stand by me - remastered 2010
# nena
# 99 luftballons - single version
# village people
# ymca
# the turtles
# happy together
# the beach boys
# good vibrations - remastered 2001
# the animals
# house of the rising sun
# lou reed
# walk on the wild side
# electric light orchestra
# mr. blue sky
# the mamas & the papas
# california dreamin'
# abba
# dancing queen
# the beatles
# in my life - remastered 2009
# bob dylan
# the times they are a-changin'
# blondie
# heart of glass - special mix
# julianne hough
# you're the one that i want - from "grease live!" music from the television event
# mgmt
# time to pretend
# mgmt
# kids
# michael jackson
# beat it
# london music works
# theme (from "eternal sunshine of the spotless mind")
# pink floyd
# another brick in the wall, pt. 2
# pink floyd
# wish you were here
# the beatles
# a day in the life - remastered 2010
# don mclean
# vincent
# america
# a horse with no name
# poolside
# hot in the shade
# supergrass
# alright
# natalia doco
# respira
# chicha libre
# popcorn andino
# chuck berry
# you never can tell
# amadou & mariam
# sabali - miike snow remix
# houndmouth
# sedona
# mumford & sons
# i will wait
# the rolling stones
# she's a rainbow
# erasure
# a little respect
# blondie
# heart of glass
# avec pas d'casque
# dommage que tu sois pris, j'embrasse mieux que je parle
# manel
# benvolgut
# r.e.m.
# losing my religion
# barry mcguire
# eve of destruction
# sufjan stevens
# come on! feel the illinoise! part i: the world's columbian exposition part ii: carl sandburg visits me in a dream
# andrew bird
# bloodless
# europe
# the final countdown
# metronomy
# love letters
# bob marley & the wailers
# redemption song
# bob marley & the wailers
# no woman no cry
# rodríguez
# crucify your mind
# iggy pop
# the passenger
# neil young
# heart of gold
# spice girls
# wannabe
# the proclaimers
# i'm gonna be (500 miles)
# the cranberries
# dreams
# dexys midnight runners
# come on eileen

# %%
dataset
# Out:
#                         id                                               name  \
# 0   383LM93rT5NdU2Le0qu4Xk                     Hotel California - Spanish Mix
# 1   2qhR4aymUGDfacDT6pzWf7                Fly Me To The Moon (In Other Words)
# 2   0P7DoyGrr4Wp9w5TotEtUC                       The Weight - Remastered 2000
# 3   6Zw0NBdfr1VlVJjDRFwUe1                                              Jimmy
# 4   57460SJgSpCXaRJ9YIYHxy                               Going Up The Country
# 5   1fDsrQ23eTAVFElUMaf38X                                       American Pie
# 6   1Jmqubf9kGkWeYQXQKImL5                                 People Are Strange
# 7   7ETpT6Pgb3bc9LRKqQ4KJb                                    Pour un instant
# 8   3ntrdR24dLkKrzSGRv1FlH                      Stand By Me - Remastered 2010
# 9   4tQfqWwXGltCVrV8NNt7FS                    99 Luftballons - Single Version
# 10  7Cp69rNBwU0gaFT8zxExlE                                               Ymca
# 11  1JO1xLtVc8mWhIoE3YaCL0                                     Happy Together
# 12  5t9KYe0Fhd5cW6UYT4qP8f                  Good Vibrations - Remastered 2001
# 13  7BY005dacJkbO6EPiOh2wb                            House Of The Rising Sun
# 14  0EFEkt29P7Icr7dO4vN6yk                              Walk on the Wild Side
# 15  2RlgNHKcydI9sayD2Df2xp                                       Mr. Blue Sky
# 16  63rva3TBizr6x1Yp5uwKfD                                California Dreamin'
# 17  4NtUY5IGzHCaqfZemmAu56                                      Dancing Queen
# 18  3KfbEIOC7YIv90FIfNSZpo                       In My Life - Remastered 2009
# 19  52vA3CYKZqZVdQnzRrdZt6                      The Times They Are A-Changin'
# 20  0a4agFmqHXxcZl1nho1BxM                       Heart Of Glass - Special Mix
# 21  2A4t62zQT77u77tPkJQhwr  You're The One That I Want - From "Grease Live...
# 22  4iG2gAwKXsOcijVaVXzRPW                                    Time to Pretend
# 23  1jJci4qxiYcOHhQR247rEU                                               Kids
# 24  1OOtq8tRnDM8kG2gqUPjAj                                            Beat It
# 25  4JvXFWVNcU8WJebrKTeqty  Theme (From "Eternal Sunshine of the Spotless ...
# 26  4gMgiXfqyzZLMhsksGmbQV                   Another Brick in the Wall, Pt. 2
# 27  6mFkJmJqdDVQ1REhVfGgd1                                 Wish You Were Here
# 28  7lQ9vPEIo4caEIctf6bYOi                A Day In The Life - Remastered 2010
# 29  0VNzEY1G4GLqcNx5qaaTl6                                            Vincent
# 30  54eZmuggBFJbV7k248bTTt                               A Horse with No Name
# 31  7v77r6ch1dszdie86DqZuB                                   Hot In The Shade
# 32  5xC8uOesnn0udeXAYlAnoY                                            Alright
# 33  0saIDjEHkPm4LgafFqsEo5                                            Respira
# 34  7kkijB89vc5uGbG1WhUFZu                                     Popcorn Andino
# 35  5zBcCuhVgll3iM4aJcaujN                                 You Never Can Tell
# 36  2XXZOjvs2DkbTDI70tINQP                          Sabali - Miike Snow Remix
# 37  65T1aY3I9qfNUDVAnaM9bq                                             Sedona
# 38  1fXiYSWmkKJfRKMegCkI11                                        I Will Wait
# 39  6KOtheMY0KN4s9TrQHr9It                                    She's A Rainbow
# 40  2RVQIq7bLi4Eu6xHPyQ46t                                   A Little Respect
# 41  41AE8ODX2JETBCa6muhSLY                                     Heart Of Glass
# 42  1YY0zmM60h0gpg6YI2icUo  Dommage que tu sois pris, j'embrasse mieux que...
# 43  6ADbZPiWZNsaCiIvsg5iq6                                          Benvolgut
# 44  31AOj9sFz2gM0O3hMARRBx                                 Losing My Religion
# 45  1Zi2ezNOqt9y9irC11xYpN                                 Eve Of Destruction
# 46  6oNs211OtOGzyZ2fvnMPHS  Come On! Feel the Illinoise! Part I: The World...
# 47  0lWLMR456FAFjlLIEBLzWf                                          Bloodless
# 48  1u9AMKIYx6O0q9KHCnfBj1                                The Final Countdown
# 49  6bW7mUdEV4jWxmdxcj8X3k                                       Love Letters
# 50  26PwuMotZqcczKLHi4Htz3                                    Redemption Song
# 51  3PQLYVskjUeRmRIfECsL0X                                    No Woman No Cry
# 52  2Xn7NadvZ56D0B2D7x2CSL                                  Crucify Your Mind
# 53  24FmdHoCr2jZGE6Z6dZbJT                                      The Passenger
# 54  5vd1QZ0tdXOExiegC55IAS                                      Heart Of Gold
# 55  1Je1IMUlBXcx1Fz0WE7oPT                                            Wannabe
# 56  67iAlVNDDdddxqSD2EZhFs                           I'm Gonna Be (500 Miles)
# 57  4JGKZS7h4Qa16gOU3oNETV                                             Dreams
# 58  3MrWxJaD2AT0W9DjWF64Vm                                     Come On Eileen
#
#                       artist  disc  duration  episode  explicit  popularity  \
# 0                Gipsy Kings     2    346600    False     False           0
# 1               Bobby Womack     1    128360    False     False          59
# 2                   The Band     1    274493    False     False          73
# 3                   Moriarty     1    264826    False     False          64
# 4                Canned Heat     1    171373    False     False          62
# 5                 Don McLean     1    516893    False     False          78
# 6                  The Doors     1    130173    False     False          76
# 7                Serge Fiori     1    202920    False     False          24
# 8                John Lennon     1    211666    False     False          66
# 9                       Nena     1    228560    False     False          35
# 10            Village People     1    284866    False     False          49
# 11               The Turtles     1    176293    False     False          76
# 12            The Beach Boys     1    219026    False     False          73
# 13               The Animals     1    271280    False     False          72
# 14                  Lou Reed     1    253960    False     False           0
# 15  Electric Light Orchestra     1    303373    False     False          81
# 16     The Mamas & The Papas     1    157960    False     False          55
# 17                      ABBA     1    230693    False     False           2
# 18               The Beatles     1    146333    False     False          76
# 19                 Bob Dylan     1    192053    False     False          67
# 20                   Blondie     1    275733    False     False          71
# 21            Julianne Hough     1    181746    False     False          40
# 22                      MGMT     1    261000    False      True          73
# 23                      MGMT     1    302840    False     False          78
# 24           Michael Jackson     1    258040    False     False          78
# 25        London Music Works     1    136533    False     False           3
# 26                Pink Floyd     1    238746    False     False          78
# 27                Pink Floyd     1    334743    False     False          77
# 28               The Beatles     1    307680    False     False          45
# 29                Don McLean     1    243493    False     False          69
# 30                   America     1    252239    False     False          78
# 31                  Poolside     1    233196    False     False          40
# 32                Supergrass     1    180880    False     False          75
# 33              Natalia Doco     1    248813    False     False          55
# 34              Chicha Libre     1    319720    False     False          39
# 35               Chuck Berry     2    161946    False     False           0
# 36           Amadou & Mariam     1    352040    False     False          32
# 37                Houndmouth     1    239881    False     False          63
# 38            Mumford & Sons     1    276720    False     False          71
# 39        The Rolling Stones     1    253720    False     False          65
# 40                   Erasure     1    213373    False     False          65
# 41                   Blondie     1    252186    False     False          66
# 42         Avec pas d'casque     1    352600    False     False          31
# 43                     Manel     1    255266    False     False          49
# 44                    R.E.M.     1    268426    False     False          85
# 45             Barry McGuire     1    215826    False     False          57
# 46            Sufjan Stevens     1    405626    False     False           0
# 47               Andrew Bird     1    389160    False     False          46
# 48                    Europe     1    307320    False     False          30
# 49                 Metronomy     1    315885    False     False          47
# 50  Bob Marley & The Wailers     1    233560    False     False          71
# 51  Bob Marley & The Wailers     1    226240    False     False          60
# 52                 Rodríguez     1    152346    False     False          65
# 53                  Iggy Pop     1    284066    False     False          48
# 54                Neil Young     1    188440    False     False          74
# 55               Spice Girls     1    173026    False     False          82
# 56           The Proclaimers     1    219466    False     False          78
# 57           The Cranberries     1    271560    False     False          78
# 58    Dexys Midnight Runners     1    287306    False     False          77
#
#     danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0          0.457      0.510000  0.8190          0.000046    0.1110    -9.072
# 1          0.589      0.397000  0.5230          0.021700    0.0967   -11.120
# 2          0.630      0.373000  0.5510          0.000058    0.1030    -9.280
# 3          0.748      0.901000  0.3050          0.000003    0.1030    -9.166
# 4          0.653      0.806000  0.2390          0.014600    0.1320   -18.540
# 5          0.531      0.699000  0.4810          0.000000    0.0842   -11.709
# 6          0.699      0.685000  0.4670          0.000000    0.3150    -8.578
# 7          0.482      0.270000  0.5130          0.001150    0.1420    -6.725
# 8          0.632      0.290000  0.5560          0.021500    0.0779   -10.138
# 9          0.647      0.091800  0.5880          0.000005    0.6570    -8.424
# 10         0.715      0.152000  0.9510          0.000000    0.3020    -6.488
# 11         0.584      0.550000  0.3670          0.000014    0.0818    -9.638
# 12         0.396      0.326000  0.4730          0.000124    0.1090    -7.670
# 13         0.295      0.000385  0.5840          0.218000    0.0996    -6.696
# 14         0.564      0.652000  0.2620          0.000204    0.0896   -19.746
# 15         0.388      0.652000  0.3380          0.000004    0.2480   -10.054
# 16         0.554      0.628000  0.6670          0.000000    0.0486   -10.226
# 17         0.539      0.382000  0.8840          0.001660    0.7600    -6.530
# 18         0.688      0.449000  0.4350          0.000000    0.1130   -11.359
# 19         0.389      0.887000  0.3960          0.000000    0.0828    -7.999
# 20         0.694      0.015000  0.5770          0.008360    0.0853   -14.630
# 21         0.730      0.315000  0.8300          0.000003    0.2410    -3.554
# 22         0.438      0.000087  0.9400          0.077700    0.3000    -3.249
# 23         0.451      0.000760  0.9310          0.004900    0.3610    -3.871
# 24         0.776      0.049500  0.8670          0.000008    0.1970    -3.704
# 25         0.462      0.895000  0.0863          0.936000    0.1040   -19.726
# 26         0.693      0.078200  0.3940          0.000694    0.2470   -15.882
# 27         0.481      0.735000  0.2620          0.011400    0.8320   -15.730
# 28         0.457      0.199000  0.3610          0.000862    0.1080   -14.520
# 29         0.419      0.908000  0.0850          0.000005    0.3400   -19.387
# 30         0.654      0.686000  0.5060          0.015500    0.1550   -17.180
# 31         0.791      0.219000  0.5110          0.945000    0.0859   -10.660
# 32         0.467      0.000479  0.9580          0.199000    0.2990    -4.808
# 33         0.685      0.643000  0.5270          0.000007    0.0969    -8.508
# 34         0.590      0.510000  0.6950          0.241000    0.6530   -10.120
# 35         0.595      0.733000  0.8350          0.000050    0.2920   -10.057
# 36         0.508      0.010200  0.7360          0.503000    0.3450    -6.088
# 37         0.394      0.040400  0.6540          0.000070    0.1120    -8.243
# 38         0.478      0.009740  0.7580          0.007170    0.3120    -5.400
# 39         0.464      0.467000  0.8240          0.018000    0.3300    -7.359
# 40         0.596      0.008080  0.5980          0.000003    0.2410   -13.409
# 41         0.726      0.001140  0.6960          0.077100    0.0563    -8.017
# 42         0.653      0.741000  0.3820          0.000000    0.1040   -10.608
# 43         0.715      0.731000  0.5280          0.000000    0.1060    -9.531
# 44         0.666      0.179000  0.8550          0.000001    0.0987    -5.051
# 45         0.613      0.387000  0.3070          0.000005    0.0870   -17.385
# 46         0.430      0.518000  0.4570          0.086800    0.1230    -8.495
# 47         0.547      0.571000  0.6620          0.001460    0.1220    -5.196
# 48         0.532      0.067000  0.8920          0.000609    0.0695    -5.215
# 49         0.774      0.367000  0.5290          0.225000    0.0923    -7.508
# 50         0.671      0.608000  0.2560          0.000000    0.0737   -10.743
# 51         0.898      0.159000  0.3650          0.000009    0.1320   -10.452
# 52         0.505      0.217000  0.5610          0.000000    0.0952    -7.772
# 53         0.500      0.079700  0.8460          0.000000    0.2410    -8.098
# 54         0.550      0.288000  0.5250          0.017200    0.1060    -8.754
# 55         0.768      0.101000  0.8640          0.000000    0.1620    -6.145
# 56         0.851      0.151000  0.5510          0.000000    0.0827    -5.177
# 57         0.551      0.003130  0.6430          0.003850    0.4210   -13.091
# 58         0.450      0.664000  0.6560          0.000003    0.2590    -7.049
#
#     mode  speechiness    tempo  time_signature  valence  \
# 0      0       0.0486  102.102               4    0.514
# 1      1       0.0404  114.252               4    0.585
# 2      1       0.0549  143.868               4    0.518
# 3      0       0.0340  126.149               4    0.263
# 4      0       0.0453   80.392               4    0.765
# 5      0       0.0600  138.450               4    0.491
# 6      0       0.0375  119.287               4    0.764
# 7      1       0.0301  123.945               4    0.529
# 8      1       0.0288  104.996               4    0.633
# 9      1       0.0490   96.661               4    0.600
# 10     1       0.1320  126.643               4    0.671
# 11     0       0.0328  120.175               4    0.588
# 12     0       0.0345  133.449               4    0.385
# 13     0       0.0345  117.200               3    0.228
# 14     1       0.1050  104.500               4    0.376
# 15     1       0.0329  177.765               4    0.478
# 16     0       0.0342  112.749               4    0.597
# 17     1       0.0403  100.812               4    0.752
# 18     1       0.0323  103.239               4    0.435
# 19     1       0.0332  171.860               3    0.585
# 20     1       0.0308  114.478               4    0.845
# 21     1       0.0920  107.022               4    0.696
# 22     1       0.0452  100.990               3    0.421
# 23     1       0.0719  122.961               4    0.172
# 24     0       0.0479  138.827               4    0.918
# 25     0       0.0346   78.016               1    0.281
# 26     1       0.0428  104.114               4    0.721
# 27     1       0.0414  122.861               4    0.375
# 28     0       0.0308   81.068               4    0.265
# 29     1       0.0362   91.509               3    0.458
# 30     0       0.0535  123.179               4    0.831
# 31     1       0.0388  102.038               3    0.358
# 32     0       0.0775  145.920               4    0.701
# 33     0       0.0313   93.017               4    0.762
# 34     0       0.0377  117.503               4    0.868
# 35     1       0.1170  157.188               4    0.919
# 36     0       0.0388  124.023               4    0.221
# 37     1       0.0346  135.188               4    0.264
# 38     1       0.0331  131.109               4    0.452
# 39     1       0.0374  109.298               4    0.539
# 40     1       0.0268  113.825               4    0.595
# 41     1       0.0333  114.691               4    0.410
# 42     1       0.0270  105.326               4    0.454
# 43     1       0.0392  129.962               4    0.855
# 44     0       0.0295  125.639               4    0.803
# 45     1       0.0414  117.305               4    0.789
# 46     0       0.0332  109.875               4    0.709
# 47     0       0.0293   82.173               4    0.498
# 48     0       0.0645  117.733               4    0.156
# 49     0       0.0682  128.195               4    0.156
# 50     1       0.0387  115.871               4    0.694
# 51     1       0.0462   98.530               4    0.563
# 52     1       0.0803   85.102               4    0.550
# 53     1       0.0457  134.937               4    0.738
# 54     1       0.0275  171.172               4    0.806
# 55     1       0.0324  110.008               4    0.891
# 56     1       0.0396  131.922               4    0.807
# 57     1       0.0353  128.661               4    0.514
# 58     1       0.0472  106.610               4    0.782
#
#                                                lyrics
# 0      Exception occurred \nHTTP Error 404: Not Found
# 1      Exception occurred \nHTTP Error 404: Not Found
# 2      Exception occurred \nHTTP Error 404: Not Found
# 3   Jimmy won't you please come home<br/>\nWhere t...
# 4   I'm going up the country, babe, don't you wann...
# 5   A long, long time ago<br/>\nI can still rememb...
# 6   People are strange when you're a stranger<br/>...
# 7      Exception occurred \nHTTP Error 404: Not Found
# 8      Exception occurred \nHTTP Error 404: Not Found
# 9      Exception occurred \nHTTP Error 404: Not Found
# 10  Young man, there's no need to feel down.<br/>\...
# 11  Imagine me and you, I do<br/>\nI think about y...
# 12     Exception occurred \nHTTP Error 404: Not Found
# 13  There is a house in New Orleans<br/>\nThey cal...
# 14  Holly came from Miami, F.L.A.<br/>\nHitch-hike...
# 15  (Morning! Today's forecast calls for blue skie...
# 16     Exception occurred \nHTTP Error 404: Not Found
# 17  Ooh, you can dance, you can jive<br/>\nHaving ...
# 18     Exception occurred \nHTTP Error 404: Not Found
# 19  Come gather 'round people<br/>\nWherever you r...
# 20       Exception occurred \nlist index out of range
# 21       Exception occurred \nlist index out of range
# 22       Exception occurred \nlist index out of range
# 23       Exception occurred \nlist index out of range
# 24       Exception occurred \nlist index out of range
# 25       Exception occurred \nlist index out of range
# 26       Exception occurred \nlist index out of range
# 27       Exception occurred \nlist index out of range
# 28       Exception occurred \nlist index out of range
# 29       Exception occurred \nlist index out of range
# 30       Exception occurred \nlist index out of range
# 31       Exception occurred \nlist index out of range
# 32       Exception occurred \nlist index out of range
# 33       Exception occurred \nlist index out of range
# 34       Exception occurred \nlist index out of range
# 35       Exception occurred \nlist index out of range
# 36       Exception occurred \nlist index out of range
# 37       Exception occurred \nlist index out of range
# 38       Exception occurred \nlist index out of range
# 39       Exception occurred \nlist index out of range
# 40       Exception occurred \nlist index out of range
# 41       Exception occurred \nlist index out of range
# 42       Exception occurred \nlist index out of range
# 43       Exception occurred \nlist index out of range
# 44       Exception occurred \nlist index out of range
# 45       Exception occurred \nlist index out of range
# 46       Exception occurred \nlist index out of range
# 47       Exception occurred \nlist index out of range
# 48       Exception occurred \nlist index out of range
# 49       Exception occurred \nlist index out of range
# 50       Exception occurred \nlist index out of range
# 51       Exception occurred \nlist index out of range
# 52       Exception occurred \nlist index out of range
# 53       Exception occurred \nlist index out of range
# 54       Exception occurred \nlist index out of range
# 55       Exception occurred \nlist index out of range
# 56       Exception occurred \nlist index out of range
# 57       Exception occurred \nlist index out of range
# 58       Exception occurred \nlist index out of range

# %%
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5Y4SqLno1w1PkXYuvgwo6p/tracks?offset=100&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-09-09T01:32:01Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lAWpj5szCSwM4rUMHYmrr'},
#        'href': 'https://api.spotify.com/v1/artists/0lAWpj5szCSwM4rUMHYmrr',
#        'id': '0lAWpj5szCSwM4rUMHYmrr',
#        'name': 'Måneskin',
#        'type': 'artist',
#        'uri': 'spotify:artist:0lAWpj5szCSwM4rUMHYmrr'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7KF1Ain9mYYlg5M46g0i4A'},
#      'href': 'https://api.spotify.com/v1/albums/7KF1Ain9mYYlg5M46g0i4A',
#      'id': '7KF1Ain9mYYlg5M46g0i4A',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735aa05015cfa7bd2943c29b21',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025aa05015cfa7bd2943c29b21',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515aa05015cfa7bd2943c29b21',
#        'width': 64}],
#      'name': "Teatro d'ira - Vol. I",
#      'release_date': '2021-03-19',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:7KF1Ain9mYYlg5M46g0i4A'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lAWpj5szCSwM4rUMHYmrr'},
#       'href': 'https://api.spotify.com/v1/artists/0lAWpj5szCSwM4rUMHYmrr',
#       'id': '0lAWpj5szCSwM4rUMHYmrr',
#       'name': 'Måneskin',
#       'type': 'artist',
#       'uri': 'spotify:artist:0lAWpj5szCSwM4rUMHYmrr'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 173346,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'ITB002100115'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4pt5fDVTg5GhEvEtlz9dKk'},
#     'href': 'https://api.spotify.com/v1/tracks/4pt5fDVTg5GhEvEtlz9dKk',
#     'id': '4pt5fDVTg5GhEvEtlz9dKk',
#     'is_local': False,
#     'name': 'I WANNA BE YOUR SLAVE',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/485950694eaee2c2887f897603a9bc4acc05c0bf?cid=1e84f4ee200940d584627e45098e5951',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4pt5fDVTg5GhEvEtlz9dKk'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-09T01:41:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62DKpfVgNt372d3Zz6TRc7'},
#        'href': 'https://api.spotify.com/v1/artists/62DKpfVgNt372d3Zz6TRc7',
#        'id': '62DKpfVgNt372d3Zz6TRc7',
#        'name': 'Teddy Hyde',
#        'type': 'artist',
#        'uri': 'spotify:artist:62DKpfVgNt372d3Zz6TRc7'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4y65KFlZgIAVqy97RXLuZq'},
#      'href': 'https://api.spotify.com/v1/albums/4y65KFlZgIAVqy97RXLuZq',
#      'id': '4y65KFlZgIAVqy97RXLuZq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e2cc9f846d54bdcb401f6962',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e2cc9f846d54bdcb401f6962',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e2cc9f846d54bdcb401f6962',
#        'width': 64}],
#      'name': 'Sock-Footed',
#      'release_date': '2018-04-02',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4y65KFlZgIAVqy97RXLuZq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62DKpfVgNt372d3Zz6TRc7'},
#       'href': 'https://api.spotify.com/v1/artists/62DKpfVgNt372d3Zz6TRc7',
#       'id': '62DKpfVgNt372d3Zz6TRc7',
#       'name': 'Teddy Hyde',
#       'type': 'artist',
#       'uri': 'spotify:artist:62DKpfVgNt372d3Zz6TRc7'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 232811,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'uscgj1853748'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1baoZlq32nBee9tcYbQYxV'},
#     'href': 'https://api.spotify.com/v1/tracks/1baoZlq32nBee9tcYbQYxV',
#     'id': '1baoZlq32nBee9tcYbQYxV',
#     'is_local': False,
#     'name': 'Sex with a Ghost',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:1baoZlq32nBee9tcYbQYxV'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-09T01:41:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hWM8sF4FGYM2mv5pEaDMJ'},
#        'href': 'https://api.spotify.com/v1/artists/0hWM8sF4FGYM2mv5pEaDMJ',
#        'id': '0hWM8sF4FGYM2mv5pEaDMJ',
#        'name': 'Charlie Mole',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hWM8sF4FGYM2mv5pEaDMJ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56VlzDua2bCTkP5cmsjdxW'},
#      'href': 'https://api.spotify.com/v1/albums/56VlzDua2bCTkP5cmsjdxW',
#      'id': '56VlzDua2bCTkP5cmsjdxW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e9ce6450ac69a6fbe28afd98',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e9ce6450ac69a6fbe28afd98',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e9ce6450ac69a6fbe28afd98',
#        'width': 64}],
#      'name': 'Dorian Gray (Original Score Soundtrack)',
#      'release_date': '2012',
#      'release_date_precision': 'year',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:56VlzDua2bCTkP5cmsjdxW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hWM8sF4FGYM2mv5pEaDMJ'},
#       'href': 'https://api.spotify.com/v1/artists/0hWM8sF4FGYM2mv5pEaDMJ',
#       'id': '0hWM8sF4FGYM2mv5pEaDMJ',
#       'name': 'Charlie Mole',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hWM8sF4FGYM2mv5pEaDMJ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 143666,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB2H71200002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/32nuyvpiQJoGUUrORIEhwu'},
#     'href': 'https://api.spotify.com/v1/tracks/32nuyvpiQJoGUUrORIEhwu',
#     'id': '32nuyvpiQJoGUUrORIEhwu',
#     'is_local': False,
#     'name': "Dorian's Theme",
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ef3bcaffda7945cef31a348118c2987269cbf9d8?cid=1e84f4ee200940d584627e45098e5951',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:32nuyvpiQJoGUUrORIEhwu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-09T01:42:36Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#        'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#        'id': '0e86yPdC41PGRkLp2Q1Bph',
#        'name': 'Mother Mother',
#        'type': 'artist',
#        'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0X7S0TEZ5NJsSxmyTnfYi2'},
#      'href': 'https://api.spotify.com/v1/albums/0X7S0TEZ5NJsSxmyTnfYi2',
#      'id': '0X7S0TEZ5NJsSxmyTnfYi2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736d82586633548d5c122ee00c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026d82586633548d5c122ee00c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516d82586633548d5c122ee00c',
#        'width': 64}],
#      'name': 'O My Heart',
#      'release_date': '2008-09-23',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0X7S0TEZ5NJsSxmyTnfYi2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#       'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#       'id': '0e86yPdC41PGRkLp2Q1Bph',
#       'name': 'Mother Mother',
#       'type': 'artist',
#       'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 213573,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAL450882106'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0VmREvheUiN0xgM5fJYQqp'},
#     'href': 'https://api.spotify.com/v1/tracks/0VmREvheUiN0xgM5fJYQqp',
#     'id': '0VmREvheUiN0xgM5fJYQqp',
#     'is_local': False,
#     'name': 'Body',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/37e0b92988620e92f2562f67a998bdc9b986ab36?cid=1e84f4ee200940d584627e45098e5951',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0VmREvheUiN0xgM5fJYQqp'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-09T01:42:43Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Avni6DLpoxtanND8mG5t8'},
#        'href': 'https://api.spotify.com/v1/artists/3Avni6DLpoxtanND8mG5t8',
#        'id': '3Avni6DLpoxtanND8mG5t8',
#        'name': 'Ghost and Pals',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Avni6DLpoxtanND8mG5t8'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5pQ3seSamWt2dGyOjFhpNz'},
#      'href': 'https://api.spotify.com/v1/albums/5pQ3seSamWt2dGyOjFhpNz',
#      'id': '5pQ3seSamWt2dGyOjFhpNz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733937671024330a766b80964a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023937671024330a766b80964a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513937671024330a766b80964a',
#        'width': 64}],
#      'name': "Honey I'm Home",
#      'release_date': '2019-08-18',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:5pQ3seSamWt2dGyOjFhpNz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Avni6DLpoxtanND8mG5t8'},
#       'href': 'https://api.spotify.com/v1/artists/3Avni6DLpoxtanND8mG5t8',
#       'id': '3Avni6DLpoxtanND8mG5t8',
#       'name': 'Ghost and Pals',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Avni6DLpoxtanND8mG5t8'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 213085,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZFZ71935711'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6mi1qJnxW164dbHszk32z5'},
#     'href': 'https://api.spotify.com/v1/tracks/6mi1qJnxW164dbHszk32z5',
#     'id': '6mi1qJnxW164dbHszk32z5',
#     'is_local': False,
#     'name': "Honey I'm Home",
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/977216ad453bc7e1ad20c8dcb29c1e1810750d58?cid=1e84f4ee200940d584627e45098e5951',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6mi1qJnxW164dbHszk32z5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-09T01:42:55Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yrzVTuk6PgF51NYgfgKXe'},
#        'href': 'https://api.spotify.com/v1/artists/0yrzVTuk6PgF51NYgfgKXe',
#        'id': '0yrzVTuk6PgF51NYgfgKXe',
#        'name': 'GRLwood',
#        'type': 'artist',
#        'uri': 'spotify:artist:0yrzVTuk6PgF51NYgfgKXe'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1R2Ky437vHsCBUGwKoVcmK'},
#      'href': 'https://api.spotify.com/v1/albums/1R2Ky437vHsCBUGwKoVcmK',
#      'id': '1R2Ky437vHsCBUGwKoVcmK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273428ea052133803b881fcde8b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02428ea052133803b881fcde8b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851428ea052133803b881fcde8b',
#        'width': 64}],
#      'name': 'Daddy',
#      'release_date': '2018-06-15',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1R2Ky437vHsCBUGwKoVcmK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yrzVTuk6PgF51NYgfgKXe'},
#       'href': 'https://api.spotify.com/v1/artists/0yrzVTuk6PgF51NYgfgKXe',
#       'id': '0yrzVTuk6PgF51NYgfgKXe',
#       'name': 'GRLwood',
#       'type': 'artist',
#       'uri': 'spotify:artist:0yrzVTuk6PgF51NYgfgKXe'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 144108,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USGAC1800077'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GxbglYySl18aZDIaGu1RU'},
#     'href': 'https://api.spotify.com/v1/tracks/0GxbglYySl18aZDIaGu1RU',
#     'id': '0GxbglYySl18aZDIaGu1RU',
#     'is_local': False,
#     'name': "I'm Yer Dad",
#     'popularity': 5,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0GxbglYySl18aZDIaGu1RU'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-09T01:48:19Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#        'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#        'id': '5Lz5CnywFeg4Rs4l76OtG2',
#        'name': 'KiNG MALA',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5vlaew4MTOnlOfon5T0vfK'},
#      'href': 'https://api.spotify.com/v1/albums/5vlaew4MTOnlOfon5T0vfK',
#      'id': '5vlaew4MTOnlOfon5T0vfK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27395ea5ca32e4d5c8d65188b97',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0295ea5ca32e4d5c8d65188b97',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485195ea5ca32e4d5c8d65188b97',
#        'width': 64}],
#      'name': 'mercy',
#      'release_date': '2021-07-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5vlaew4MTOnlOfon5T0vfK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#       'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#       'id': '5Lz5CnywFeg4Rs4l76OtG2',
#       'name': 'KiNG MALA',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 177788,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ9H32100021'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4PHZkpHmsig3EihQneGOMt'},
#     'href': 'https://api.spotify.com/v1/tracks/4PHZkpHmsig3EihQneGOMt',
#     'id': '4PHZkpHmsig3EihQneGOMt',
#     'is_local': False,
#     'name': 'mercy',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/31fcecc98ab44fc64c020d3298059aff4817eaae?cid=1e84f4ee200940d584627e45098e5951',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4PHZkpHmsig3EihQneGOMt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-09T01:48:22Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#        'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#        'id': '5Lz5CnywFeg4Rs4l76OtG2',
#        'name': 'KiNG MALA',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6A32eeBvBEw5bh6w2PDPyf'},
#      'href': 'https://api.spotify.com/v1/albums/6A32eeBvBEw5bh6w2PDPyf',
#      'id': '6A32eeBvBEw5bh6w2PDPyf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27388726cc9069a3677ae7ef7c6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0288726cc9069a3677ae7ef7c6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485188726cc9069a3677ae7ef7c6',
#        'width': 64}],
#      'name': 'If I Try to Find You',
#      'release_date': '2020-09-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6A32eeBvBEw5bh6w2PDPyf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#       'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#       'id': '5Lz5CnywFeg4Rs4l76OtG2',
#       'name': 'KiNG MALA',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 227817,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZ9H32000041'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6T677KlIOsgJNAJaoVWZut'},
#     'href': 'https://api.spotify.com/v1/tracks/6T677KlIOsgJNAJaoVWZut',
#     'id': '6T677KlIOsgJNAJaoVWZut',
#     'is_local': False,
#     'name': 'If I Try to Find You',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6T677KlIOsgJNAJaoVWZut'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-09T01:48:24Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#        'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#        'id': '5Lz5CnywFeg4Rs4l76OtG2',
#        'name': 'KiNG MALA',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0FlT3HWoxUWcVTZHV2oYfd'},
#      'href': 'https://api.spotify.com/v1/albums/0FlT3HWoxUWcVTZHV2oYfd',
#      'id': '0FlT3HWoxUWcVTZHV2oYfd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f09f395bd8eef832952ede3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f09f395bd8eef832952ede3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f09f395bd8eef832952ede3f',
#        'width': 64}],
#      'name': 'GEMiNi',
#      'release_date': '2020-12-04',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:0FlT3HWoxUWcVTZHV2oYfd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lz5CnywFeg4Rs4l76OtG2'},
#       'href': 'https://api.spotify.com/v1/artists/5Lz5CnywFeg4Rs4l76OtG2',
#       'id': '5Lz5CnywFeg4Rs4l76OtG2',
#       'name': 'KiNG MALA',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Lz5CnywFeg4Rs4l76OtG2'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
# ...
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 110270,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEE862300763'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3zrwQpsIrGxLUwxq4iMvfk'},
#     'href': 'https://api.spotify.com/v1/tracks/3zrwQpsIrGxLUwxq4iMvfk',
#     'id': '3zrwQpsIrGxLUwxq4iMvfk',
#     'is_local': False,
#     'name': 'Sweet Dreams (Sky like Dreams) - Sped up',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bcd02564a465667ac7bcd779e7cd54799ff915e8?cid=1e84f4ee200940d584627e45098e5951',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3zrwQpsIrGxLUwxq4iMvfk'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-06-11T14:13:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3JsMj0DEzyWc0VDlHuy9Bx'},
#        'href': 'https://api.spotify.com/v1/artists/3JsMj0DEzyWc0VDlHuy9Bx',
#        'id': '3JsMj0DEzyWc0VDlHuy9Bx',
#        'name': 'Supertramp',
#        'type': 'artist',
#        'uri': 'spotify:artist:3JsMj0DEzyWc0VDlHuy9Bx'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1zcm3UvHNHpseYOUfd0pna'},
#      'href': 'https://api.spotify.com/v1/albums/1zcm3UvHNHpseYOUfd0pna',
#      'id': '1zcm3UvHNHpseYOUfd0pna',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735405ef9e393f5f1e53b4b42e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025405ef9e393f5f1e53b4b42e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515405ef9e393f5f1e53b4b42e',
#        'width': 64}],
#      'name': 'Breakfast In America (Deluxe Edition)',
#      'release_date': '1979-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:1zcm3UvHNHpseYOUfd0pna'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3JsMj0DEzyWc0VDlHuy9Bx'},
#       'href': 'https://api.spotify.com/v1/artists/3JsMj0DEzyWc0VDlHuy9Bx',
#       'id': '3JsMj0DEzyWc0VDlHuy9Bx',
#       'name': 'Supertramp',
#       'type': 'artist',
#       'uri': 'spotify:artist:3JsMj0DEzyWc0VDlHuy9Bx'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 159346,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71021483'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4a5pNRjwmzYQuEY1E7O6pj'},
#     'href': 'https://api.spotify.com/v1/tracks/4a5pNRjwmzYQuEY1E7O6pj',
#     'id': '4a5pNRjwmzYQuEY1E7O6pj',
#     'is_local': False,
#     'name': 'Breakfast In America - 2010 Remastered',
#     'popularity': 76,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4a5pNRjwmzYQuEY1E7O6pj'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-07-12T13:41:01Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/fjs07o44hm09c5rmgfi96q5jc'},
#     'href': 'https://api.spotify.com/v1/users/fjs07o44hm09c5rmgfi96q5jc',
#     'id': 'fjs07o44hm09c5rmgfi96q5jc',
#     'type': 'user',
#     'uri': 'spotify:user:fjs07o44hm09c5rmgfi96q5jc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#        'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#        'id': '0e86yPdC41PGRkLp2Q1Bph',
#        'name': 'Mother Mother',
#        'type': 'artist',
#        'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0X7S0TEZ5NJsSxmyTnfYi2'},
#      'href': 'https://api.spotify.com/v1/albums/0X7S0TEZ5NJsSxmyTnfYi2',
#      'id': '0X7S0TEZ5NJsSxmyTnfYi2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736d82586633548d5c122ee00c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026d82586633548d5c122ee00c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516d82586633548d5c122ee00c',
#        'width': 64}],
#      'name': 'O My Heart',
#      'release_date': '2008-09-23',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0X7S0TEZ5NJsSxmyTnfYi2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#       'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#       'id': '0e86yPdC41PGRkLp2Q1Bph',
#       'name': 'Mother Mother',
#       'type': 'artist',
#       'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 194320,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAL450882109'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2y51QpLzI5qbWfCcSx9Tu1'},
#     'href': 'https://api.spotify.com/v1/tracks/2y51QpLzI5qbWfCcSx9Tu1',
#     'id': '2y51QpLzI5qbWfCcSx9Tu1',
#     'is_local': False,
#     'name': 'Wrecking Ball',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c0182d49a81e64f1515c36837877460ffde2e83b?cid=1e84f4ee200940d584627e45098e5951',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2y51QpLzI5qbWfCcSx9Tu1'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 100,
#  'previous': 'https://api.spotify.com/v1/playlists/5Y4SqLno1w1PkXYuvgwo6p/tracks?offset=0&limit=100&additional_types=track',
#  'total': 184}

# %%
get_lyrics('quevedo',"columbia")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data mining and visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/aladelca/Library/CloudStorage/OneDrive-McGillUniversity/MMA/Data%20mining%20and%20visualization/group_assignment/INSY_662_MMA/data/extract_data.ipynb#ch0000006?line=0'>1</a> get_lyrics('quevedo',"columbia")
#
# TypeError: get_lyrics() missing 1 required positional argument: 'proxies'
